# %% [markdown]
# # Read in the data

# %%
import os
import sys
import re

# %%
def read_data(file):
    '''
    Read each text file into a string
    '''
    f = open(file, 'r', encoding='utf-8', errors='ignore')
    text = f.read()
    f.close()
    return text

def folder_list(path):
    '''
    Reads each text file in a folder and concatenates each file into a bigger string
    Parameter 'path' is the path of your local folder
    '''
    filelist = os.listdir(path)
    text = []
    for infile in filelist:
        file = os.path.join(path, infile)
        text_data = read_data(file)
        text += [text_data]
    return text

# %%
data = folder_list('clustered_articles/')
#data = folder_list('test/')
#data = read_data('clustered_articles/cluster_9.txt')

# %%
data[1]

# %% [markdown]
# # TF-IDF

# %%
## run once ##
#!pip install nltk

# %%
## run once, install everything ##
#import nltk
#import ssl
#
#try:
#    _create_unverified_https_context = ssl._create_unverified_context
#except AttributeError:
#    pass
#else:
#    ssl._create_default_https_context = _create_unverified_https_context
#
#nltk.download()

# %%
import math

from nltk import sent_tokenize, word_tokenize, PorterStemmer
from nltk.corpus import stopwords

# %%
# sourced from - https://towardsdatascience.com/text-summarization-using-tf-idf-e64a0644ace3
def _create_frequency_table(text_string) -> dict:
    """
    we create a dictionary for the word frequency table.
    For this, we should only use the words that are not part of the stopWords array.
    Removing stop words and making frequency table
    Stemmer - an algorithm to bring words to its root word.
    :rtype: dict
    """
    stopWords = set(stopwords.words("english"))
    words = word_tokenize(text_string)
    ps = PorterStemmer()

    freqTable = dict()
    for word in words:
        word = ps.stem(word)
        if word in stopWords:
            continue
        if word in freqTable:
            freqTable[word] += 1
        else:
            freqTable[word] = 1

    return freqTable


def _create_frequency_matrix(sentences):
    frequency_matrix = {}
    stopWords = set(stopwords.words("english"))
    ps = PorterStemmer()

    for sent in sentences:
        freq_table = {}
        words = word_tokenize(sent)
        for word in words:
            word = word.lower()
            word = ps.stem(word)
            if word in stopWords:
                continue

            if word in freq_table:
                freq_table[word] += 1
            else:
                freq_table[word] = 1

        frequency_matrix[sent[:15]] = freq_table

    return frequency_matrix


def _create_tf_matrix(freq_matrix):
    tf_matrix = {}

    for sent, f_table in freq_matrix.items():
        tf_table = {}

        count_words_in_sentence = len(f_table)
        for word, count in f_table.items():
            tf_table[word] = count / count_words_in_sentence

        tf_matrix[sent] = tf_table

    return tf_matrix


def _create_documents_per_words(freq_matrix):
    word_per_doc_table = {}

    for sent, f_table in freq_matrix.items():
        for word, count in f_table.items():
            if word in word_per_doc_table:
                word_per_doc_table[word] += 1
            else:
                word_per_doc_table[word] = 1

    return word_per_doc_table


def _create_idf_matrix(freq_matrix, count_doc_per_words, total_documents):
    idf_matrix = {}

    for sent, f_table in freq_matrix.items():
        idf_table = {}

        for word in f_table.keys():
            idf_table[word] = math.log10(total_documents/float(count_doc_per_words[word]))

        idf_matrix[sent] = idf_table

    return idf_matrix


def _create_tf_idf_matrix(tf_matrix, idf_matrix):
    tf_idf_matrix = {}

    for (sent1, f_table1), (sent2, f_table2) in zip(tf_matrix.items(),idf_matrix.items()):

        tf_idf_table = {}

        for (word1, value1), (word2, value2) in zip(f_table1.items(),
                                                    f_table2.items()):  # here, keys are the same in both the table
            tf_idf_table[word1] = float(value1 * value2)

        tf_idf_matrix[sent1] = tf_idf_table

    return tf_idf_matrix

# %%
def _score_sentences(tf_idf_matrix) -> dict:
    """
    score a sentence by its word's TF
    Basic algorithm: adding the TF frequency of every non-stop word in a sentence divided by total no of words in a sentence.
    :rtype: dict
    """

    sentenceValue = {}

    for sent, f_table in tf_idf_matrix.items():
        total_score_per_sentence = 0

        count_words_in_sentence = len(f_table)
        for word, score in f_table.items():
            total_score_per_sentence += score

        sentenceValue[sent] = total_score_per_sentence/count_words_in_sentence

    return sentenceValue


def _find_average_score(sentenceValue) -> int:
    """
    Find the average score from the sentence value dictionary
    :rtype: int
    """
    sumValues = 0
    for entry in sentenceValue:
        sumValues += sentenceValue[entry]

    # Average value of a sentence from original summary_text
    average = (sumValues/len(sentenceValue))

    return average


def _generate_summary(sentences, sentenceValue, threshold):
    sentence_count = 0
    summary = ''

    for sentence in sentences:
        if sentence[:15] in sentenceValue and sentenceValue[sentence[:15]]>=(threshold):
            summary += " " + sentence
            sentence_count += 1

    return summary

# s is a scale for the threshold -> higher values means only higher rated TF-IDF 
# sentences get chosen (more strict).
def run_summarization(text, s):
    """
    :param text: Plain summary_text of long article
    :return: summarized summary_text
    """

    '''
    We already have a sentence tokenizer, so we just need 
    to run the sent_tokenize() method to create the array of sentences.
    '''
    # 1 Sentence Tokenize
    sentences = sent_tokenize(text)
    total_documents = len(sentences)
    #print(sentences)

    # 2 Create the Frequency matrix of the words in each sentence.
    freq_matrix = _create_frequency_matrix(sentences)
    #print(freq_matrix)

    '''
    Term frequency (TF) is how often a word appears in a document, divided by how many words are there in a document.
    '''
    # 3 Calculate TermFrequency and generate a matrix
    tf_matrix = _create_tf_matrix(freq_matrix)
    #print(tf_matrix)

    # 4 creating table for documents per words
    count_doc_per_words = _create_documents_per_words(freq_matrix)
    #print(count_doc_per_words)

    '''
    Inverse document frequency (IDF) is how unique or rare a word is.
    '''
    # 5 Calculate IDF and generate a matrix
    idf_matrix = _create_idf_matrix(freq_matrix, count_doc_per_words, total_documents)
    #print(idf_matrix)

    # 6 Calculate TF-IDF and generate a matrix
    tf_idf_matrix = _create_tf_idf_matrix(tf_matrix, idf_matrix)
    #print(tf_idf_matrix)

    # 7 Important Algorithm: score the sentences
    sentence_scores = _score_sentences(tf_idf_matrix)
    #print(sentence_scores)

    # 8 Find the threshold
    threshold = _find_average_score(sentence_scores)
    #print(threshold)

    # 9 Important Algorithm: Generate the summary
    summary = _generate_summary(sentences, sentence_scores, s*threshold)
    return summary

# %%
for cluster_idx in range(len(data)):
    result = run_summarization(data[cluster_idx], 2)
    print(str(cluster_idx) + ':')
    print(result)
    print()

# %%
result = run_summarization(data[0], 2)
print(result)

# %% [markdown]
# # Transformers

# %%
## run once ##
#!pip install tensorflow torch  # make sure either tensorflow or torch is installed
#!pip install transformers

# %%
from transformers import pipeline

# %%
# Initialize the HuggingFace summarization pipeline
# note: model is developed by facebook (fine-tuned using CNN - a news summarization dataset)
summarizer = pipeline("summarization", model="facebook/bart-large-cnn", max_length=2**31, truncation=True) # summarization uses BART model


for cluster_idx in range(len(data)):
    result = summarizer(data[cluster_idx], min_length=75, max_length=300)
    print(str(cluster_idx) + ':')
    print(result)
    print()
# Out:
# 0:
# [{'summary_text': 'Qatar Airways flight to Doha marks a breakthrough in the bumpy coordination between the U.S. and Afghanistans new Taliban rulers. A dayslong standoff over charter planes at another airport has left dozens of passengers stranded. It was not immediately clear how many Americans were on board Thursday and how many were still in Afghanistan. The Taliban have repeatedly said foreigners and Afghans with proper travel documents could leave.'}]
#
# 1:
# [{'summary_text': 'John Hinckley Jr. was 25 when he shot and wounded the 40th U.S. president outside a Washington hotel. He was found not guilty by reason of insanity in 1981. A federal judge says he can be freed from all remaining restrictions next year if he continues to follow those rules and remains mentally stable. The Ronald Reagan Presidential Foundation says it is "saddened" by the court\'s plan.'}]
#
# 2:
# [{'summary_text': 'A new Discovery+ series, "Curse of the Chippendales," exposes the intimate details of owner Steve Banerjee\'s murder-for-hire plot. "What I went through, you\'ll never believe," said former performer Read Scot. In 1979, banerjee opened the first Chipp Endales, featuring male strippers, in west Los Angeles.'}]
#
# 3:
# [{'summary_text': 'Join us on Tuesday at 7 p.m. ET for a first-of-its-kind @disneyonbroadway TikTok event LIVE from the Minskoff Theatre. The live stream will include a special pre-show hosted by Broadway cast member Adrienne Walker (Nala) and an exclusive behind-the-scenes look at the people who bring "The Lion King" to life.'}]
#
# 4:
# [{'summary_text': 'Teacher at Harns Marsh Middle School in Lehigh Acres, near Fort Myers, alerted school administrators. A search of an eighth grader\'s backpack did not turn up a gun, but administrators allegedly found a map that "contains markings indicating the location of each of the school\'s interior cameras" "We were one second away from a Columbine here," the local sheriff said.'}]
#
# 5:
# [{'summary_text': 'In January, Alaska had the highest per capita coronavirus vaccination rate in the nation. Now, hospitals are overwhelmed with COVID-19 patients, and the states largest hospital is rationing care. "It has brought us to the breaking point," one hospital official said. Alaska had a strong initial vaccine rollout, delivering doses to remote areas of the state by helicopters, planes, dog sleds and ferries.'}]
#
# 6:
# [{'summary_text': "A Catholic high school student was killed and another teenager was injured when gunfire erupted. The suspected gunman remained on the run Monday, police said. The shooting unfolded around 8:15 p.m. Saturday at the Haunted Hills Hayride, about 13 miles southeast of Pittsburgh. Overall, 84 people have died across eight states due to Ida's wrath as a Category 4 storm."}]
#
# 7:
# [{'summary_text': "British court says it will formally provide notice to Prince Andrew of sexual assault lawsuit. Prince's legal team has argued that lawyers for accuser are not authorized to serve summons. Virginia Giuffre, 38, sued the prince in a U.S. federal court last month. Prince has denied her allegations in a New York federal court, has denied allegations in New York."}]
#
# 8:
# [{'summary_text': 'Nikkita Brown was walking her dog in a closed park in Chicago on Aug. 28. She says a white police officer drove up to her and told her to leave the area immediately. Brown says the officer followed her as she walked out of the park. The officer allegedly told her, "You can go to jail," according to a video taken by Brown.'}]
#
# 9:
# [{'summary_text': 'Gavin Newsom faces a recall election on Tuesday. President Joe Biden and other top Democrats are campaigning for Newsom. Biden: "The decision you\'re about to make isn\'t just going to have a huge impact on California, it\'s going to reverberate around the nation" Newsom: "We may have defeated Donald Trump, but we have not defeated Trumpism"'}]
#
# 10:
# [{'summary_text': 'John Arthur Getreu found guilty of murdering 21-year-old Janet Ann Taylor. Taylor, a college sophomore, was the youngest daughter of legendary Stanford University football coach, Chuck Taylor. Cold case detectives used genetic genealogy to identify Getreus. He has also been charged in the 1973 murder of Stanford graduate, Leslie Perlov, and will be tried next year.'}]
#
# 11:
# [{'summary_text': 'Congress has until the end of the day Thursday to pass a temporary funding bill. If Congress fails to act, a government shutdown could begin as early as Friday. During a shutdown, federal employees are either sent home or asked to work without pay. A full government shutdown would mean federal agencies close their doors or reduce their operations to only what is deemed essential, such as the U.S. Postal Service.'}]
#
# 12:
# [{'summary_text': 'Carl Asaro was one of the first responders at ground zero on 9/11. Of the 15 people who left from Engine 54, Ladder 4 that day, none returned home. Four of the six Asaro children went on to continue his legacy as firefighters. "I think for us to give back and live a life of service is one way to really feel connected with my dad," Carl Jr. said.'}]
#
# 13:
# [{'summary_text': 'Tropical Storm Nicholas strengthens from a tropical depression to a tropical storm. The storm is expected to become better organized and strengthen as it moves toward the Texas coast. Flash flood watches are now in effect from Brownsville, Texas, to Lake Charles, Louisiana. The outer bands of Nicholas could potentially affect some regions along the Louisiana coast that were devastated by Hurricane Ida last month.'}]
#
# 14:
# [{'summary_text': '50 teachers will be treated to a 4-Day, 3-Night stay at Walt Disney World Resort. Winners will participate in a half-day inspiration session with Disney leaders and storytellers. Pixar Fest is back and even bigger than before, with a month-long celebration of all things Pixar. This year, Disney also announced that we have teamed up with Starlight Childrens Foundation to design Pixar-themed hospital gowns.'}]
#
# 15:
# [{'summary_text': 'Shelley Lynn Thornton, 51, says she was told her birth mother was Norma McCorvey in 1989. At the time, abortion was still illegal in Texas, and she was a plaintiff in the Roe vs. Wade case. She says she never agreed to meet her biological mother in person. "She never did anything in her life to get back that privilege," Thornton says.'}]
#
# 16:
# [{'summary_text': 'Michigan lawmaker files unflattering text messages in court against another lawmaker. Rep. Steve Marino said he hoped Rep. Mari Manoogian\'s "car explodes on the way in" Former Facebook employee turned whistleblower testifies before Senate Commerce subcommittee. She alleges blatant disregard from Facebook executives when they learned their platform could have harmful effects on democracy and the mental health of children.'}]
#
# 17:
# [{'summary_text': "A British court says it intends to formally provide notice to Prince Andrew of a sexual assault lawsuit filed against him in New York. The court's decision came over the objections of the prince's legal team, who have argued that lawyers for the accuser are not authorized to receive assistance from the U.K. courts. A lawyer for Virginia Giuffre said Wednesday that he regards the objections as an effort to delay or avoid the prince having to face the allegations in court."}]
#
# 18:
# [{'summary_text': 'Joffreys coffee is the official coffee of Disneyland Resort and Walt Disney World Resort. Joffreys poured its first cup of coffee for Disney guests at Disneys Typhoon Lagoon Water Park back in 1995. For a limited time, Joffrey kiosks at our four theme parks will offer special sips in honor of the 50th anniversary celebration. Remys Ratatouille Adventure will open in EPCOT on Oct. 1, just in time for The Worlds Most Magical Celebration.'}]
#
# 19:
# [{'summary_text': 'Bryan Raymond planted the tree in a stubborn pothole along Honda Drive in south Fort Myers. "If we have to maintain it and make sure nobody gets hurt, we are going to put something obvious there," he said. Some who work along the road say anything is better than potholes. Michael Sussmann, an attorney for the Perkins Coie law firm, was indicted Thursday.'}]
#
# 20:
# [{'summary_text': 'Jesse Benton, 43, of Louisville, Kentucky, was accused in an indictment unsealed Monday. Trump pardoned Benton in December after his conviction in a case involving false records. Benton and Roy Douglas "Doug" Wead were accused of conspiracy to solicit and cause an illegal campaign contribution by a Russian foreign national during the 2016 presidential election. Wead attorney Jay Sekulow said Wead pleaded not guilty.'}]
# 21:
# [{'summary_text': '"Aulani, Lei Hiwahiwa" written and performed by two of our very own Aulani cast members: Angela Morales and Eric Lee. Rocio Cintron, Product Design Manager for Disney Preschool, shared how she infuses her background into the work she does, which allows her to learn and celebrate other cultures as well. In describing her favorite Disney treat at the Parks, Rocio said her favorite ride at Disneyland is Mad Tea Party because the teacups are sweet and colorful.'}]
#
# 22:
# [{'summary_text': "A new ABC News/Ipsos poll finds Americans' confidence in Joe Biden is eroding. The president's overall approval rating has worsened since late August. Dissatisfaction among Republicans and independents is fueling the decline. A bill to rebuild the nation's infrastructure is the most pressing priority for Biden this week, as it will be brought up for a vote on Thursday."}]
#
# 23:
# [{'summary_text': 'John Hinckley Jr. could be released from all court supervision by June 2022, if he continues to follow rules. President Joe Biden is set to deliver remarks Thursday on a new strategy to stop the spread of the contagious delta variant. Biden has limited legal authority to institute a broad vaccine mandate for most Americans. The administration did announce Tuesday that at least 75% of adults in the U.S. have at least one dose of COVID-19.'}]
#
# 24:
# [{'summary_text': 'Sen. Bernie Sanders, I-Vt., said Sunday the $3.5 trillion budget resolution price tag will likely be lowered. House progressives have warned leadership they will not vote on President Joe Bidens bipartisan infrastructure bill until the larger human infrastructure bill is also ready for a vote. The budget resolution calls for investments in climate change policy, child care and other social programs, and is wider in scope than the infrastructure bill.'}]
#
# 25:
# [{'summary_text': 'A U.S. intelligence officer suffered symptoms linked to "Havana syndrome" He was traveling with CIA Director William Burns in India earlier this month. Experts are in the process of verifying the officer\'s symptoms. There are at least 200 cases under investigation, half of them involving intelligence personnel.. A company that most. of the legal sports betting industry uses to verify that its customers are. where they say they are reported a record number of transactions over the first weekend of the. NFL season.'}]
#
# 26:
# [{'summary_text': 'The investigation will focus on "harm to prisoners resulting from prisoner-on-prisoner violence" It will also look into sexual abuse of gay, lesbian and transgender prisoners by both prisoners and staff. Georgia Gov. Brian Kemp\'s office referred a request for comment on the investigation to the state Department of Corrections. "The GDC is committed to the safety of all of the offenders in its custody," spokeswoman says.'}]
#
# 27:
# [{'summary_text': 'California Gov. Gavin Newsom and his Republican rivals are making their final pitches to voters. The race concludes Tuesday, and more than a third of voters have already mailed in their ballot or voted early in person. More than 7.7 million people have already voted, according to tracking data firm Political Data Inc., a political data firm that works with Democrats. The GOP is expecting a larger turnout on Election Day given many Republicans are skeptical of voting by mail.'}]
#
# 28:
# [{'summary_text': 'Taylor and Angel Beery are the next Disney Magic Makers. Walker Beery, age 9, was diagnosed with brain cancer in 2017. Walker told his parents he wanted to inspire other kids to help fight pediatric cancer. The group "Kids Join The Fight" has kicked off a grassroots movement of kids and families around the country. To nominate a local hero to become a Disney Magic Maker, visit DisneyMagicMakers.com.'}]
#
# 29:
# [{'summary_text': 'The death toll from Hurricane Ida and its aftermath continues to rise. More than 10,400 personnel are helping fight 14 "active large wildfires" in California. The KNP Complex fires has burned over 11,300 acres and is 0% contained. The Windy Fire, which was also ignited by lightning on Sept. 9, has burned 6,800 acres.'}]
#
# 30:
# [{'summary_text': 'Body "consistent with the description of" Gabby Petito found in Wyoming. Petito, 22, went missing while on a cross-country road trip with her boyfriend. Her boyfriend, named a person of interest, has not been seen since Tuesday. An estimated 200,000 young immigrants living legally in U.S. for years are aging out of the program.'}]
#
# 31:
# [{'summary_text': 'Australia\'s "Fortress Australia" approach to the pandemic has been breached. The government is now planning to "live with the virus" rather than stamp it out entirely. New South Wales and Victoria have posted record numbers of daily infections in recent weeks. Australia is now administering doses at higher rates than peaks seen in the U.S., but supply remains an issue.'}]
#
# 32:
# [{'summary_text': "Pfizer releases first safety data about COVID-19 vaccines for children ages 5 to 11. A smaller dose of Pfizer vaccine -- one-third the amount given to adults and adolescents -- provided robust and adequate immune responses. If the FDA agrees with Pfizer's assessment, finally those younger than 12 can get vaccinated -- in this case, if authorized, with the smaller dosage."}]
#
# 33:
# [{'summary_text': 'A federal judge approved a plan Monday to unconditionally release John Hinckley Jr. from all remaining court-ordered restrictions, if he continues to follow rules and agrees to undergo regular mental health examinations. U.S. District Court Judge Paul L. Friedman said he plans on issuing his ruling on the plan later this week. The Ronald Reagan Presidential Foundation said in a statement that it was "saddened" by the court\'s plan.'}]
#
# 34:
# [{'summary_text': 'Obama says he\'s "absolutely confident" that the center will benefit the local community. The Obama Presidential Center will include a library, museum, gardens, and a children\'s playground. Park preservationists have challenged the construction in court, citing environmental concerns. Obama was born in Hawaii but spent much of his formative years on Chicago\'s South Side, which is home to a predominantly Black community.'}]
#
# 35:
# [{'summary_text': 'Bryan Raymond planted the tree in a stubborn pothole along Honda Drive in south Fort Myers. Raymond: "If we have to maintain it and make sure nobody gets hurt, we are going to put something obvious there" County officials said, its up to the business owners to maintain the street. "I love it, I think its hilarious. We should have more of these," said Scott Shein.'}]
# Your max_length is set to 300, but you input_length is only 242. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)
# 36:
# [{'summary_text': 'President Joe Biden meets with House Democrats, White House officials say. His move comes as Democrats are at an impasse over passing his agenda. House Speaker Nancy Pelosi has twice had to delay a vote on a $1.2 trillion bipartisan infrastructure plan. progressive Democrats are vowing to defeat it unless they also get aVote on $3.5 trillion social safety net and climate policy measure.'}]
#
# 37:
# [{'summary_text': 'Dr. Anthony Fauci defended the White House\'s plan to provide COVID-19 vaccine booster shots before the Food and Drug Administration voted to only provide those shots to Americans 65 and older and immunocompromised. "The goal of this particular decision was to prevent people from getting serious disease who are at risk, such as the elderly and those that have underlying conditions," he said.'}]
#
# 38:
# [{'summary_text': 'A federal judge approved a plan Monday to unconditionally release John Hinckley Jr. from all remaining court-ordered restrictions, if he continues to follow rules. U.S. District Court Judge Paul L. Friedman said he plans on issuing his ruling on the plan later this week. Dawn Jackson, a Native American cultural advisor at Disney, began working on the project as an Imagineer on the Story Development team.'}]
#
# 39:
# [{'summary_text': "California Gov. Gavin Newsom and his Republican rivals are making their final pitches to voters. A recent poll shows Newsom likely to survive, and Democrats are making a stronger showing in early voting. Republicans angry with Newsom's policies on immigration, crime and a host of other issues sparked the recall drive. More than a third of voters have already mailed in their ballot or voted early in person."}]
#
# 40:
# [{'summary_text': "Two planned skyscrapers, a performing arts center and a church are still unfinished at the site. The memorial plaza with its twin reflecting pools opened in 2011. The Ronald O. Perelman Performing Arts Center is under construction just to the west of 2 World Trade Center's future site and is scheduled to open in 2023. The St. Nicholas Orthodox Church and National Shrine is replacing a public park surrounded by a small park."}]
#
# 41:
# [{'summary_text': 'A federal court orders the FEC to rule on pending complaints against the NRA. The complaints allege the NRA used shell entities to illegally coordinate campaign spending. The NRA says the suit is "a baseless effort engineered by anti-gun groups" A federal judge approved a plan to unconditionally release John Hinckley Jr. from all court-ordered restrictions, if he continues to follow rules.'}]
#
# 42:
# [{'summary_text': '"Disney Enchantment," the brand-new nighttime spectacular coming to Magic Kingdom Park as part of "The Worlds Most Magical Celebration," features dazzling fireworks, beloved Disney music and immersive projection effects that extend from Cinderella Castle down Main Street, U.S.A. Philip Lawrence not only wrote "You Are the Magic" but also performs the song in "Disney enchantment" along with actor and singer Kayla Alvarez. Check back here on Disney Parks Blog and follow #DisneyWorld50 on social media for regular updates.'}]
#
# 43:
# [{'summary_text': 'Three firefighters are in critical condition; the remaining victims are expected to be released from the hospital. At least half of the building appeared to be badly damaged and piles of debris from the building could be seen strewn around the structure. An explosion occurred while fire crews were investigating the scene, causing the two-story building to partially collapse. It is unclear what caused the explosion, fire officials said.'}]
#
# 44:
# [{'summary_text': "A hostess in New York City was assaulted after asking patrons for proof of vaccination, police say. The incident took place at Carmine's Italian Restaurant in the Upper West Side neighborhood of Manhattan. Police: Three women from Texas assaulted the 24-year-old hostess and broke her necklace during the attack. The NYPD has not released the names of the accused, each of whom was taken into custody."}]
#
# 45:
# [{'summary_text': 'Bryan Raymond planted the tree in a stubborn pothole along Honda Drive in south Fort Myers. Because Honda Drive is a private street, county officials said, its up to the business owners. Raymond: "If we have to maintain it and make sure nobody gets hurt, we are going to put something obvious there" A white catfish caught in Connecticut last month smashed a state record and could be a world record.'}]
#
# 46:
# [{'summary_text': 'Bryan Raymond planted the tree in a stubborn pothole along Honda Drive in south Fort Myers. "If we have to maintain it and make sure nobody gets hurt, we are going to put something obvious there," he says. An inmate on a New York City jail barge died Wednesday after a medical emergency. It is at least the 12th death of a city inmate this year and the second this week.'}]
#
# 47:
# [{'summary_text': "A federal judge approved a plan Monday to unconditionally release John Hinckley Jr., who had shot and wounded former President Ronald Reagan in 1981. U.S. District Court Judge Paul L. Friedman said he plans on issuing his ruling on the plan later this week. The White House chief medical adviser Dr. Anthony Fauci defended the White House's earlier plan to begin rolling out the shots to the general population this month."}]
#
# 48:
# [{'summary_text': 'Border Patrol chief defends use of horseback patrol as vital tool for law enforcement. Department of Homeland Security says it is investigating the incident and will respond if needed. About 10,400 migrants are currently at the encampment, according to official updates. The Biden administration is also considering a request from Texas Gov. Greg Abbott that President Joe Biden declare an emergency in the state.'}]

# %% [markdown]
# # Transformer Translation (Extra)

# %%
# some translation testing with transformer
translator = pipeline("translation_en_to_de")
print(translator("".join(list(summarized[0].values())), max_length=300))
